# %%
import pandas as pd

# %%
PROJECT_ID = "algebraic-notch-313219"

# %%
BUCKET_NAME = "gs://my-first-bucket"

# %%
if PROJECT_ID == "" or PROJECT_ID is None or PROJECT_ID == "algebraic-notch-313219":
    # Get your GCP project id from gcloud
    shell_output = ! gcloud config list --format 'value(core.project)' 2>/dev/null
    PROJECT_ID = shell_output[0]
    print("Project ID:", PROJECT_ID)
# Out:
# Project ID: algebraic-notch-313219

# %%
from datetime import datetime

TIMESTAMP = datetime.now().strftime("%Y%m%d%H%M%S")

# %%
if BUCKET_NAME == "" or BUCKET_NAME is None or BUCKET_NAME == "gs://my-first-bucket":
    BUCKET_NAME = "gs://" + PROJECT_ID + "aip-" + TIMESTAMP

# %%
import google.cloud.aiplatform as aip

# %%
aip.init(project=PROJECT_ID, staging_bucket=BUCKET_NAME)

# %%
IMPORT_FILE = "gs://cloud-ai-platform-47ebb270-074a-4330-aaba-fff9e976aee4/datasets/adult_income"

# %%
count = ! gsutil cat $IMPORT_FILE | wc -l
print("Number of Examples", int(count[0]))

print("First 10 rows")
! gsutil cat $IMPORT_FILE | head

heading = ! gsutil cat $IMPORT_FILE | head -n1
label_column = str(heading).split(",")[-1].split("'")[0]
print("Label Column Name", label_column)
if label_column is None:
    raise Exception("label column missing")
# Out:
# Number of Examples 32562
# First 10 rows
# age,workclass,functional_weight,education,education_num,marital_status,occupation,relationship,race,sex,capital_gain,capital_loss,hours_per_week,native_country,income_bracket
# 39, Private,297847, 9th,5, Married-civ-spouse, Other-service, Wife, Black, Female,3411,0,34, United-States, <=50K
# 72, Private,74141, 9th,5, Married-civ-spouse, Exec-managerial, Wife, Asian-Pac-Islander, Female,0,0,48, United-States, >50K
# 45, Private,178215, 9th,5, Married-civ-spouse, Machine-op-inspct, Wife, White, Female,0,0,40, United-States, >50K
# 31, Private,86958, 9th,5, Married-civ-spouse, Exec-managerial, Wife, White, Female,0,0,40, United-States, <=50K
# 55, Private,176012, 9th,5, Married-civ-spouse, Tech-support, Wife, White, Female,0,0,23, United-States, <=50K
# 30, Private,61272, 9th,5, Married-civ-spouse, Machine-op-inspct, Wife, White, Female,0,0,40, Portugal, <=50K
# 46, Self-emp-inc,161386, 9th,5, Married-civ-spouse, Adm-clerical, Wife, White, Female,0,0,50, United-States, <=50K
# 28, Private,209801, 9th,5, Married-civ-spouse, Machine-op-inspct, Wife, White, Female,0,0,40, United-States, <=50K
# 37, Private,171090, 9th,5, Married-civ-spouse, Machine-op-inspct, Wife, Black, Female,0,0,48, United-States, <=50K
# Label Column Name income_bracket

# %%
dataset = aip.TabularDataset.create(
    display_name="Income" + "_" + TIMESTAMP, gcs_source=[IMPORT_FILE]
)

print(dataset.resource_name)
# Out:
# INFO:google.cloud.aiplatform.datasets.dataset:Creating TabularDataset
# INFO:google.cloud.aiplatform.datasets.dataset:Create TabularDataset backing LRO: projects/301473280362/locations/us-central1/datasets/3737965700484956160/operations/2473885288296873984
# INFO:google.cloud.aiplatform.datasets.dataset:TabularDataset created. Resource name: projects/301473280362/locations/us-central1/datasets/3737965700484956160
# INFO:google.cloud.aiplatform.datasets.dataset:To use this TabularDataset in another session:
# INFO:google.cloud.aiplatform.datasets.dataset:ds = aiplatform.TabularDataset('projects/301473280362/locations/us-central1/datasets/3737965700484956160')
# projects/301473280362/locations/us-central1/datasets/3737965700484956160

# %%
dag = aip.AutoMLTabularTrainingJob(
    display_name="income_" + TIMESTAMP,
    optimization_prediction_type="classification",
    optimization_objective="minimize-log-loss",
)

print(dag)
# Out:
# <google.cloud.aiplatform.training_jobs.AutoMLTabularTrainingJob object at 0x7fbde7c020d0>

# %%
model = dag.run(
    dataset=dataset,
    model_display_name="income_" + TIMESTAMP,
    training_fraction_split=0.6,
    validation_fraction_split=0.2,
    test_fraction_split=0.2,
    budget_milli_node_hours=8000,
    disable_early_stopping=False,
    target_column=label_column,
)
# Out:
# INFO:google.cloud.aiplatform.training_jobs:No column transformations provided, so now retrieving columns from dataset in order to set default column transformations.
# INFO:google.cloud.aiplatform.training_jobs:The column transformation of type 'auto' was set for the following columns: ['age', 'workclass', 'capital_gain', 'native_country', 'education_num', 'functional_weight', 'marital_status', 'race', 'sex', 'hours_per_week', 'occupation', 'capital_loss', 'relationship', 'education'].
# INFO:google.cloud.aiplatform.training_jobs:View Training:
# https://console.cloud.google.com/ai/platform/locations/us-central1/training/2506087716131700736?project=301473280362
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# INFO:google.cloud.aiplatform.training_jobs:AutoMLTabularTrainingJob run completed. Resource name: projects/301473280362/locations/us-central1/trainingPipelines/2506087716131700736
# INFO:google.cloud.aiplatform.training_jobs:Model available at projects/301473280362/locations/us-central1/models/4597669444196499456

# %%
models = aip.Model.list(filter="display_name=income_" + TIMESTAMP)

# %%
REGION = "us-central1"

# %%
client_options = {"api_endpoint": f"{REGION}-aiplatform.googleapis.com"}
model_service_client = aip.gapic.ModelServiceClient(client_options=client_options)

# %%
model_evaluations = model_service_client.list_model_evaluations(
    parent=models[0].resource_name
)

# %%
model_evaluation = list(model_evaluations)[0]
print(model_evaluation)
# Out:
# name: "projects/301473280362/locations/us-central1/models/4597669444196499456/evaluations/8520853186664803680"
# metrics_schema_uri: "gs://google-cloud-aiplatform/schema/modelevaluation/classification_metrics_1.0.0.yaml"
# metrics {
#   struct_value {
#     fields {
#       key: "auPrc"
#       value {
#         number_value: 0.95041203
#       }
#     }
#     fields {
#       key: "auRoc"
#       value {
#         number_value: 0.9484026
#       }
#     }
#     fields {
#       key: "confidenceMetrics"
#       value {
#         list_value {
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: -0.01
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.6666667
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.6666667
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "6599"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.5
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.5
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6599"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.6666667
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "6599"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.5
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6599"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.01
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.7347552
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "2"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "4761"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.721473
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.5808241
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9996969
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "1838"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6597"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.02
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.75914085
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "7"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "4176"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.63282317
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.6121842
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9989392
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "2423"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6592"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.03
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.77294344
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "17"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "3850"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.5834217
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.63094324
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9974238
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "2749"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6582"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.04
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.782438
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "23"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "3634"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.5506895
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.64407444
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9965146
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "2965"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6576"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.05
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.7900403
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "31"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "3460"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.52432185
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.6549661
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9953023
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3139"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6568"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.06
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.7965258
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "42"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "3308"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.50128806
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.6646731
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9936354
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3291"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6557"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.07
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.80149305
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "50"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "3194"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.48401272
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.6721749
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9924231
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3405"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6549"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.08
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8066564
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "55"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "3082"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.46704045
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.6798255
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9916654
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3517"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6544"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.09
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.81144136
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "60"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2979"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.45143205
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.6870141
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9909077
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3620"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6539"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.1
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.81541634
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "72"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2883"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.43688437
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.6936238
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.98908925
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3716"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6527"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.11
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8194165
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "83"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2789"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.4226398
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.7002687
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.98742235
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3810"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6516"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.12
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.82286656
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "100"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2698"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.40884984
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.70664346
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9848462
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3901"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6499"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.13
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.82620317
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "110"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2620"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.39702985
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.71237236
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9833308
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "3979"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6489"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.14
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8286684
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "130"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2545"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.3856645
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.71766144
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.98030007
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "4054"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6469"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.15
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8320989
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "139"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2468"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.37399605
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.7235663
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9789362
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "4131"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6460"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.16
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8351776
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "146"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2401"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.363843
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.7288231
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9778754
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "4198"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6453"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.17
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8378414
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "156"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2338"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.35429612
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.7337433
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9763601
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "4261"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6443"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.18
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8397725
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "176"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2275"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.3447492
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.73844564
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9733293
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "4324"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6423"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.19
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.84175265
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "192"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2217"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.33596
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.7429267
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9709047
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "4382"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6407"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.2
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8434943
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "207"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2165"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.32808
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.74699074
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.9686316
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "4434"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "6392"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.21
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.8454045
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.8671011
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "220"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "2113"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.32020003
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.13289893
# ...
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "3462"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "31"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.0046976814
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.0046976814
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.99021465
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.99021465
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.47537506
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.47537506
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "6568"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "3137"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.96
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.6178251
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.6178251
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "3639"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "23"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.0034853765
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.0034853765
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.99228966
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.99228966
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.44855282
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.44855282
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "6576"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "2960"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.97
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.5863248
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.5863248
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "3855"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "17"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.002576148
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.002576148
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.99384284
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.99384284
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.41582057
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.41582057
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "6582"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "2744"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.98
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.53395474
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.53395474
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "4193"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "7"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.0010607668
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.0010607668
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.99709904
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.99709904
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.3646007
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.3646007
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "6592"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "2406"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 0.99
#                 }
#               }
#               fields {
#                 key: "f1Score"
#                 value {
#                   number_value: 0.43155894
#                 }
#               }
#               fields {
#                 key: "f1ScoreAt1"
#                 value {
#                   number_value: 0.43155894
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "4783"
#                 }
#               }
#               fields {
#                 key: "falsePositiveCount"
#                 value {
#                   string_value: "1"
#                 }
#               }
#               fields {
#                 key: "falsePositiveRate"
#                 value {
#                   number_value: 0.00015153812
#                 }
#               }
#               fields {
#                 key: "falsePositiveRateAt1"
#                 value {
#                   number_value: 0.00015153812
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 0.9994497
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 0.9994497
#                 }
#               }
#               fields {
#                 key: "recall"
#                 value {
#                   number_value: 0.2751932
#                 }
#               }
#               fields {
#                 key: "recallAt1"
#                 value {
#                   number_value: 0.2751932
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "6598"
#                 }
#               }
#               fields {
#                 key: "truePositiveCount"
#                 value {
#                   string_value: "1816"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "6599"
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "6599"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "confidenceThreshold"
#                 value {
#                   number_value: 1.01
#                 }
#               }
#               fields {
#                 key: "falseNegativeCount"
#                 value {
#                   string_value: "6599"
#                 }
#               }
#               fields {
#                 key: "precision"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "precisionAt1"
#                 value {
#                   number_value: 1.0
#                 }
#               }
#               fields {
#                 key: "trueNegativeCount"
#                 value {
#                   string_value: "6599"
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     fields {
#       key: "confusionMatrix"
#       value {
#         struct_value {
#           fields {
#             key: "annotationSpecs"
#             value {
#               list_value {
#                 values {
#                   struct_value {
#                     fields {
#                       key: "displayName"
#                       value {
#                         string_value: " <=50K"
#                       }
#                     }
#                     fields {
#                       key: "id"
#                       value {
#                         string_value: "0"
#                       }
#                     }
#                   }
#                 }
#                 values {
#                   struct_value {
#                     fields {
#                       key: "displayName"
#                       value {
#                         string_value: " >50K"
#                       }
#                     }
#                     fields {
#                       key: "id"
#                       value {
#                         string_value: "1"
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#           fields {
#             key: "rows"
#             value {
#               list_value {
#                 values {
#                   list_value {
#                     values {
#                       number_value: 4684.0
#                     }
#                     values {
#                       number_value: 303.0
#                     }
#                   }
#                 }
#                 values {
#                   list_value {
#                     values {
#                       number_value: 574.0
#                     }
#                     values {
#                       number_value: 1038.0
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     fields {
#       key: "logLoss"
#       value {
#         number_value: 0.28727046
#       }
#     }
#   }
# }
# create_time {
#   seconds: 1652285475
#   nanos: 372661000
# }
# slice_dimensions: "annotationSpec"
# model_explanation {
#   mean_attributions {
#     feature_attributions {
#       struct_value {
#         fields {
#           key: "age"
#           value {
#             number_value: 0.07009226652167604
#           }
#         }
#         fields {
#           key: "capital_gain"
#           value {
#             number_value: 0.04249845027141091
#           }
#         }
#         fields {
#           key: "capital_loss"
#           value {
#             number_value: 0.008498563824335812
#           }
#         }
#         fields {
#           key: "education"
#           value {
#             number_value: 0.005086011369615353
#           }
#         }
#         fields {
#           key: "education_num"
#           value {
#             number_value: 0.09282019871243333
#           }
#         }
#         fields {
#           key: "functional_weight"
#           value {
#             number_value: 0.018826034453828338
#           }
#         }
#         fields {
#           key: "hours_per_week"
#           value {
#             number_value: 0.03295941984901965
#           }
#         }
#         fields {
#           key: "marital_status"
#           value {
#             number_value: 0.13244708719607082
#           }
#         }
#         fields {
#           key: "native_country"
#           value {
#             number_value: 0.005485658188980328
#           }
#         }
#         fields {
#           key: "occupation"
#           value {
#             number_value: 0.08825288986868073
#           }
#         }
#         fields {
#           key: "race"
#           value {
#             number_value: 0.00434357564844527
#           }
#         }
#         fields {
#           key: "relationship"
#           value {
#             number_value: 0.020861775419665548
#           }
#         }
#         fields {
#           key: "sex"
#           value {
#             number_value: 0.019607141201209603
#           }
#         }
#         fields {
#           key: "workclass"
#           value {
#             number_value: 0.015751283097816534
#           }
#         }
#       }
#     }
#   }
# }

# %%
endpoint = model.deploy(machine_type="n1-standard-2")
# Out:
# INFO:google.cloud.aiplatform.models:Creating Endpoint
# INFO:google.cloud.aiplatform.models:Create Endpoint backing LRO: projects/301473280362/locations/us-central1/endpoints/8212287532231032832/operations/6075076140333006848
# INFO:google.cloud.aiplatform.models:Endpoint created. Resource name: projects/301473280362/locations/us-central1/endpoints/8212287532231032832
# INFO:google.cloud.aiplatform.models:To use this Endpoint in another session:
# INFO:google.cloud.aiplatform.models:endpoint = aiplatform.Endpoint('projects/301473280362/locations/us-central1/endpoints/8212287532231032832')
# INFO:google.cloud.aiplatform.models:Deploying model to Endpoint : projects/301473280362/locations/us-central1/endpoints/8212287532231032832
# INFO:google.cloud.aiplatform.models:Deploy Endpoint model backing LRO: projects/301473280362/locations/us-central1/endpoints/8212287532231032832/operations/555914796990464000
# INFO:google.cloud.aiplatform.models:Endpoint model deployed. Resource name: projects/301473280362/locations/us-central1/endpoints/8212287532231032832

# %%
INSTANCE = { 
    "age": "43",
    "workclass": "Private",
    "functional_weight": "262439",
    "education": "HS-grad",
    "education_num": "9",
    "marital_status": "Married-civ-spouse",
    "occupation": "Other-service",
    "relationship": "Wife",
    "race": "White",
    "sex": "Male",
    "capital_gain": "0",
    "capital_loss": "0",
    "hours_per_week": "40",
    "native_country": "United-States",
}

# %%
instances_list = [INSTANCE]

prediction = endpoint.explain(instances_list)
print(prediction)
# Out:
# Prediction(predictions=[{'scores': [0.855384111404419, 0.1446159183979034], 'classes': [' <=50K', ' >50K']}], deployed_model_id='1798757042576424960', explanations=[attributions {
#   baseline_output_value: 0.46345165371894836
#   instance_output_value: 0.855384111404419
#   feature_attributions {
#     struct_value {
#       fields {
#         key: "age"
#         value {
#           number_value: -0.01891795947001531
#         }
#       }
#       fields {
#         key: "capital_gain"
#         value {
#           number_value: 0.0
#         }
#       }
#       fields {
#         key: "capital_loss"
#         value {
#           number_value: 0.0
#         }
#       }
#       fields {
#         key: "education"
#         value {
#           number_value: 0.0
#         }
#       }
#       fields {
#         key: "education_num"
#         value {
#           number_value: 0.08390970184252812
#         }
#       }
#       fields {
#         key: "functional_weight"
#         value {
#           number_value: 0.02690481910338769
#         }
#       }
#       fields {
#         key: "hours_per_week"
#         value {
#           number_value: 0.0
#         }
#       }
#       fields {
#         key: "marital_status"
#         value {
#           number_value: 0.0
#         }
#       }
#       fields {
#         key: "native_country"
#         value {
#           number_value: 2.292486337515024e-09
#         }
#       }
#       fields {
#         key: "occupation"
#         value {
#           number_value: 0.3000358962095701
#         }
#       }
#       fields {
#         key: "race"
#         value {
#           number_value: -2.292486337515024e-09
#         }
#       }
#       fields {
#         key: "relationship"
#         value {
#           number_value: 0.0
#         }
#       }
#       fields {
#         key: "sex"
#         value {
#           number_value: 0.0
#         }
#       }
#       fields {
#         key: "workclass"
#         value {
#           number_value: 0.0
#         }
#       }
#     }
#   }
#   output_index: 0
#   output_display_name: " <=50K"
#   approximation_error: 0.0009025827804402354
#   output_name: "scores"
# }
# ])

# %%
import numpy as np

# %%
try:
    label = np.argmax(prediction[0][0]["scores"])
    cls = prediction[0][0]["classes"][label]
    print("Predicted Value:", cls, prediction[0][0]["scores"][label])
except:
    pass
# Out:
# Predicted Value:  <=50K 0.855384111404419
